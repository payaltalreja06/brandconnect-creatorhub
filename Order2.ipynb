# %%
import pandas as pd
df = pd.read_csv('Order2.csv')
df.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
 
transactions = df.apply(lambda r: r.dropna().tolist(), axis=1).tolist()

from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
x= te.fit_transform(transactions)

da=pd.DataFrame(x,columns=te.columns_)

from mlxtend.frequent_patterns import apriori,association_rules
frequent_items = apriori(da,min_support=0.001,use_colnames=True)
rules = association_rules(frequent_items,metric='confidence')
rules
# Out:
#                                           antecedents          consequents  \
# 0                                   (pancakes, bacon)          (spaghetti)
# 1                        (frozen smoothie, black tea)               (milk)
# 2                                 (salmon, black tea)      (mineral water)
# 3                              (chicken, protein bar)          (spaghetti)
# 4                            (red wine, tomato sauce)          (chocolate)
# ..                                                ...                  ...
# 68         (soup, frozen vegetables, olive oil, milk)      (mineral water)
# 69       (frozen vegetables, shrimp, spaghetti, milk)      (mineral water)
# 70       (frozen vegetables, turkey, spaghetti, milk)      (mineral water)
# 71  (frozen vegetables, tomatoes, olive oil, miner...          (spaghetti)
# 72  (milk, spaghetti, mineral water, chocolate, gr...  (frozen vegetables)
#
# ...

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Load original dataset
df_raw = pd.read_csv("Order2.csv", header=None)

# Convert each row to a clean list
transactions = df_raw.apply(lambda r: r.dropna().tolist(), axis=1).tolist()

# Encode using TransactionEncoder
te = TransactionEncoder()
x = te.fit_transform(transactions)
df_te = pd.DataFrame(x, columns=te.columns_)

# Run Apriori
frequent_items = apriori(df_te, min_support=0.1, use_colnames=True)

# Generate Rules
rules = association_rules(frequent_items, metric='confidence', min_threshold=0.3)

rules[['antecedents','consequents','support','confidence','lift']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 from mlxtend.frequent_patterns import apriori, association_rules
#       5 # Load original dataset
# ----> 6 df_raw = pd.read_csv("Order2.csv", header=None)
#       8 # Convert each row to a clean list
#       9 transactions = df_raw.apply(lambda r: r.dropna().tolist(), axis=1).tolist()
#
# ...
